# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="llama3.2:1b")

# %%
res = llm.invoke("Hello,I am pragya")

# %%
res.content
# Out:
# 'Hello Pragya! How can I assist you today?'
