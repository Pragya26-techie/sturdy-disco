# %%
5+5
# Out:
# 10

# %% [markdown]
# #### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4")

# %%
res = llm.invoke("who is pm of India?")
res
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 res = llm.invoke("who is pm of India?")
#       2 res
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)
#     390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
#     397             stop=stop,
#     398             callbacks=config.get("callbacks"),
#     399             tags=config.get("tags"),
#     400             metadata=config.get("metadata"),
#     401             run_name=config.get("run_name"),
#     402             run_id=config.pop("run_id", None),
#     403             **kwargs,
#     404         ).generations[0][0],
#     405     ).message
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:1025, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1016 @override
#    1017 def generate_prompt(
#    1018     self,
#    (...)
#    1022     **kwargs: Any,
#    1023 ) -> LLMResult:
#    1024     prompt_messages = [p.to_messages() for p in prompts]
# -> 1025     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:842, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     839 for i, m in enumerate(input_messages):
#     840     try:
#     841         results.append(
# --> 842             self._generate_with_cache(
#     843                 m,
#     844                 stop=stop,
#     845                 run_manager=run_managers[i] if run_managers else None,
#     846                 **kwargs,
#     847             )
#     848         )
#     849     except BaseException as e:
#     850         if run_managers:
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:1091, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1089     result = generate_from_stream(iter(chunks))
#    1090 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1091     result = self._generate(
#    1092         messages, stop=stop, run_manager=run_manager, **kwargs
#    1093     )
#    1094 else:
#    1095     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_openai\chat_models\base.py:1213, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1211     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1212         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1213     raise e
#    1214 if (
#    1215     self.include_response_headers
#    1216     and raw_response is not None
#    1217     and hasattr(raw_response, "headers")
#    1218 ):
#    1219     generation_info = {"headers": dict(raw_response.headers)}
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_openai\chat_models\base.py:1208, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1201         return _construct_lc_result_from_responses_api(
#    1202             response,
#    1203             schema=original_schema_obj,
#    1204             metadata=generation_info,
#    1205             output_version=self.output_version,
#    1206         )
#    1207     else:
# -> 1208         raw_response = self.client.with_raw_response.create(**payload)
#    1209         response = raw_response.parse()
#    1210 except Exception as e:
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\openai\_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     365 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\openai\resources\chat\completions\completions.py:1284, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1235 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1236 def create(
#    1237     self,
#    (...)
#    1281     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1282 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1283     validate_response_format(response_format)
# -> 1284     return self._post(
#    1285         "/chat/completions",
#    1286         body=maybe_transform(
#    1287             {
#    1288                 "messages": messages,
#    1289                 "model": model,
#    1290                 "audio": audio,
#    1291                 "frequency_penalty": frequency_penalty,
#    1292                 "function_call": function_call,
#    1293                 "functions": functions,
#    1294                 "logit_bias": logit_bias,
#    1295                 "logprobs": logprobs,
#    1296                 "max_completion_tokens": max_completion_tokens,
#    1297                 "max_tokens": max_tokens,
#    1298                 "metadata": metadata,
#    1299                 "modalities": modalities,
#    1300                 "moderation": moderation,
#    1301                 "n": n,
#    1302                 "parallel_tool_calls": parallel_tool_calls,
#    1303                 "prediction": prediction,
#    1304                 "presence_penalty": presence_penalty,
#    1305                 "prompt_cache_key": prompt_cache_key,
#    1306                 "prompt_cache_options": prompt_cache_options,
#    1307                 "prompt_cache_retention": prompt_cache_retention,
#    1308                 "reasoning_effort": reasoning_effort,
#    1309                 "response_format": response_format,
#    1310                 "safety_identifier": safety_identifier,
#    1311                 "seed": seed,
#    1312                 "service_tier": service_tier,
#    1313                 "stop": stop,
#    1314                 "store": store,
#    1315                 "stream": stream,
#    1316                 "stream_options": stream_options,
#    1317                 "temperature": temperature,
#    1318                 "tool_choice": tool_choice,
#    1319                 "tools": tools,
#    1320                 "top_logprobs": top_logprobs,
#    1321                 "top_p": top_p,
#    1322                 "user": user,
#    1323                 "verbosity": verbosity,
#    1324                 "web_search_options": web_search_options,
#    1325             },
#    1326             completion_create_params.CompletionCreateParamsStreaming
#    1327             if stream
#    1328             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1329         ),
#    1330         options=make_request_options(
#    1331             extra_headers=extra_headers,
#    1332             extra_query=extra_query,
#    1333             extra_body=extra_body,
#    1334             timeout=timeout,
#    1335             security={"bearer_auth": True},
#    1336         ),
#    1337         cast_to=ChatCompletion,
#    1338         stream=stream or False,
#    1339         stream_cls=Stream[ChatCompletionChunk],
#    1340     )
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\openai\_base_client.py:1360, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1351     warnings.warn(
#    1352         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1353         "Please pass raw bytes via the `content` parameter instead.",
#    1354         DeprecationWarning,
#    1355         stacklevel=2,
#    1356     )
#    1357 opts = FinalRequestOptions.construct(
#    1358     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1359 )
# -> 1360 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\openai\_base_client.py:1133, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1130             err.response.read()
#    1132         log.debug("Re-raising status error")
# -> 1133         raise self._make_status_error_from_response(err.response) from None
#    1135     break
#    1137 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `gpt-4` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}

# %% [markdown]
# ##### Connect with google gemini model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
# Out:
# c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\google\api_core\_python_version_support.py:242: FutureWarning: You are using a non-supported Python version (3.9.25). Google will not post any further updates to google.api_core supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.api_core.
#   warnings.warn(message, FutureWarning)
# c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\google\auth\__init__.py:54: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)
# c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\google\oauth2\__init__.py:40: FutureWarning: You are using a Python version 3.9 past its end of life. Google will update google-auth with critical bug fixes on a best-effort basis, but not with any other fixes or features. Please upgrade your Python version, and then update google-auth.
#   warnings.warn(eol_message.format("3.9"), FutureWarning)
# c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\google\api_core\_python_version_support.py:242: FutureWarning: You are using a non-supported Python version (3.9.25). Google will not post any further updates to google.ai.generativelanguage_v1beta supporting this Python version. Please upgrade to the latest Python version, or at least Python 3.10, and then update google.ai.generativelanguage_v1beta.
#   warnings.warn(message, FutureWarning)

# %%
res = llm.invoke("What is GenAI ? Explain me in short")

# %%
print(res.content)
# Out:
# **GenAI** stands for **Generative Artificial Intelligence**.
#
# In short, it's a type of AI that can **create new content** – like text, images, music, or code – rather than just analyzing or processing existing data. It does this by learning patterns from massive datasets and then using those patterns to generate novel outputs.

# %% [markdown]
# #### Connect with OpenAI model

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")

# %%
res = llm.invoke("How to find largest number from our list in python")
print(res.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 res = llm.invoke("How to find largest number from our list in python")
#       2 print(res.content)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)
#     390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
#     397             stop=stop,
#     398             callbacks=config.get("callbacks"),
#     399             tags=config.get("tags"),
#     400             metadata=config.get("metadata"),
#     401             run_name=config.get("run_name"),
#     402             run_id=config.pop("run_id", None),
#     403             **kwargs,
#     404         ).generations[0][0],
#     405     ).message
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:1025, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1016 @override
#    1017 def generate_prompt(
#    1018     self,
#    (...)
#    1022     **kwargs: Any,
#    1023 ) -> LLMResult:
#    1024     prompt_messages = [p.to_messages() for p in prompts]
# -> 1025     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:842, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     839 for i, m in enumerate(input_messages):
#     840     try:
#     841         results.append(
# --> 842             self._generate_with_cache(
#     843                 m,
#     844                 stop=stop,
#     845                 run_manager=run_managers[i] if run_managers else None,
#     846                 **kwargs,
#     847             )
#     848         )
#     849     except BaseException as e:
#     850         if run_managers:
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:1091, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1089     result = generate_from_stream(iter(chunks))
#    1090 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1091     result = self._generate(
#    1092         messages, stop=stop, run_manager=run_manager, **kwargs
#    1093     )
#    1094 else:
#    1095     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_openai\chat_models\base.py:1213, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1211     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1212         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1213     raise e
#    1214 if (
#    1215     self.include_response_headers
#    1216     and raw_response is not None
#    1217     and hasattr(raw_response, "headers")
#    1218 ):
#    1219     generation_info = {"headers": dict(raw_response.headers)}
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_openai\chat_models\base.py:1208, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1201         return _construct_lc_result_from_responses_api(
#    1202             response,
#    1203             schema=original_schema_obj,
#    1204             metadata=generation_info,
#    1205             output_version=self.output_version,
#    1206         )
#    1207     else:
# -> 1208         raw_response = self.client.with_raw_response.create(**payload)
#    1209         response = raw_response.parse()
#    1210 except Exception as e:
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\openai\_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     365 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\openai\resources\chat\completions\completions.py:1284, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1235 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1236 def create(
#    1237     self,
#    (...)
#    1281     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1282 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1283     validate_response_format(response_format)
# -> 1284     return self._post(
#    1285         "/chat/completions",
#    1286         body=maybe_transform(
#    1287             {
#    1288                 "messages": messages,
#    1289                 "model": model,
#    1290                 "audio": audio,
#    1291                 "frequency_penalty": frequency_penalty,
#    1292                 "function_call": function_call,
#    1293                 "functions": functions,
#    1294                 "logit_bias": logit_bias,
#    1295                 "logprobs": logprobs,
#    1296                 "max_completion_tokens": max_completion_tokens,
#    1297                 "max_tokens": max_tokens,
#    1298                 "metadata": metadata,
#    1299                 "modalities": modalities,
#    1300                 "moderation": moderation,
#    1301                 "n": n,
#    1302                 "parallel_tool_calls": parallel_tool_calls,
#    1303                 "prediction": prediction,
#    1304                 "presence_penalty": presence_penalty,
#    1305                 "prompt_cache_key": prompt_cache_key,
#    1306                 "prompt_cache_options": prompt_cache_options,
#    1307                 "prompt_cache_retention": prompt_cache_retention,
#    1308                 "reasoning_effort": reasoning_effort,
#    1309                 "response_format": response_format,
#    1310                 "safety_identifier": safety_identifier,
#    1311                 "seed": seed,
#    1312                 "service_tier": service_tier,
#    1313                 "stop": stop,
#    1314                 "store": store,
#    1315                 "stream": stream,
#    1316                 "stream_options": stream_options,
#    1317                 "temperature": temperature,
#    1318                 "tool_choice": tool_choice,
#    1319                 "tools": tools,
#    1320                 "top_logprobs": top_logprobs,
#    1321                 "top_p": top_p,
#    1322                 "user": user,
#    1323                 "verbosity": verbosity,
#    1324                 "web_search_options": web_search_options,
#    1325             },
#    1326             completion_create_params.CompletionCreateParamsStreaming
#    1327             if stream
#    1328             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1329         ),
#    1330         options=make_request_options(
#    1331             extra_headers=extra_headers,
#    1332             extra_query=extra_query,
#    1333             extra_body=extra_body,
#    1334             timeout=timeout,
#    1335             security={"bearer_auth": True},
#    1336         ),
#    1337         cast_to=ChatCompletion,
#    1338         stream=stream or False,
#    1339         stream_cls=Stream[ChatCompletionChunk],
#    1340     )
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\openai\_base_client.py:1360, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1351     warnings.warn(
#    1352         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1353         "Please pass raw bytes via the `content` parameter instead.",
#    1354         DeprecationWarning,
#    1355         stacklevel=2,
#    1356     )
#    1357 opts = FinalRequestOptions.construct(
#    1358     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1359 )
# -> 1360 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\openai\_base_client.py:1133, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1130             err.response.read()
#    1132         log.debug("Re-raising status error")
# -> 1133         raise self._make_status_error_from_response(err.response) from None
#    1135     break
#    1137 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model="claude-opus-5")
res  = llm.invoke("Who is pm of india?")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[6], line 3
#       1 from langchain_anthropic import ChatAnthropic
#       2 llm = ChatAnthropic(model="claude-opus-5")
# ----> 3 res  = llm.invoke("Who is pm of india?")
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)
#     390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
#     397             stop=stop,
#     398             callbacks=config.get("callbacks"),
#     399             tags=config.get("tags"),
#     400             metadata=config.get("metadata"),
#     401             run_name=config.get("run_name"),
#     402             run_id=config.pop("run_id", None),
#     403             **kwargs,
#     404         ).generations[0][0],
#     405     ).message
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:1025, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1016 @override
#    1017 def generate_prompt(
#    1018     self,
#    (...)
#    1022     **kwargs: Any,
#    1023 ) -> LLMResult:
#    1024     prompt_messages = [p.to_messages() for p in prompts]
# -> 1025     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:842, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     839 for i, m in enumerate(input_messages):
#     840     try:
#     841         results.append(
# --> 842             self._generate_with_cache(
#     843                 m,
#     844                 stop=stop,
#     845                 run_manager=run_managers[i] if run_managers else None,
#     846                 **kwargs,
#     847             )
#     848         )
#     849     except BaseException as e:
#     850         if run_managers:
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_core\language_models\chat_models.py:1091, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1089     result = generate_from_stream(iter(chunks))
#    1090 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1091     result = self._generate(
#    1092         messages, stop=stop, run_manager=run_manager, **kwargs
#    1093     )
#    1094 else:
#    1095     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_anthropic\chat_models.py:1766, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1764     data = self._create(payload)
#    1765 except anthropic.BadRequestError as e:
# -> 1766     _handle_anthropic_bad_request(e)
#    1767 return self._format_output(data, **kwargs)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_anthropic\chat_models.py:1764, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1762 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1763 try:
# -> 1764     data = self._create(payload)
#    1765 except anthropic.BadRequestError as e:
#    1766     _handle_anthropic_bad_request(e)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\langchain_anthropic\chat_models.py:1623, in ChatAnthropic._create(self, payload)
#    1621 if "betas" in payload:
#    1622     return self._client.beta.messages.create(**payload)
# -> 1623 return self._client.messages.create(**payload)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\anthropic\resources\messages\messages.py:1049, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1042     warnings.warn(
#    1043         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1044         UserWarning,
#    1045         stacklevel=3,
#    1046     )
#    1048 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1049 return self._post(
#    1050     "/v1/messages",
#    1051     body=maybe_transform(
#    1052         {
#    1053             "max_tokens": max_tokens,
#    1054             "messages": messages,
#    1055             "model": model,
#    1056             "cache_control": cache_control,
#    1057             "container": container,
#    1058             "inference_geo": inference_geo,
#    1059             "metadata": metadata,
#    1060             "output_config": output_config,
#    1061             "service_tier": service_tier,
#    1062             "stop_sequences": stop_sequences,
#    1063             "stream": stream,
#    1064             "system": system,
#    1065             "temperature": temperature,
#    1066             "thinking": thinking,
#    1067             "tool_choice": tool_choice,
#    1068             "tools": tools,
#    1069             "top_k": top_k,
#    1070             "top_p": top_p,
#    1071         },
#    1072         message_create_params.MessageCreateParamsStreaming
#    1073         if stream
#    1074         else message_create_params.MessageCreateParamsNonStreaming,
#    1075     ),
#    1076     options=make_request_options(
#    1077         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1078     ),
#    1079     cast_to=Message,
#    1080     stream=stream or False,
#    1081     stream_cls=Stream[RawMessageStreamEvent],
#    1082 )
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\anthropic\_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\PRAGYA\Desktop\GENAI-Series\venv\lib\site-packages\anthropic\_base_client.py:1194, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1191     if not response.is_closed:
#    1192         response.read()
# -> 1194     raise self._make_status_error_from_response(response) from None
#    1196 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CfB1wjwaK77jNBrZvT22H'}

# %% [markdown]
# #### static prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
prompts = [
    ("system","You are a java developer."),  ###(type,)-->"system","ai","user"
    ("user","How to sort the array,")
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# Okay, as a Java developer, I can tell you there are several ways to sort an array in Java, each with its own advantages and use cases. Here are the most common and recommended approaches:
#
# **1. Using `Arrays.sort()` (The Easiest and Most Common Way)**
#
# This is the go-to method for most scenarios. The `java.util.Arrays` class provides overloaded `sort()` methods for primitive arrays (like `int[]`, `char[]`, `double[]`) and object arrays (like `String[]`, `Integer[]`).
#
# *   **For Primitive Arrays (e.g., `int[]`)**
#
#     ```java
#     import java.util.Arrays;
#
#     public class SortPrimitiveArray {
#         public static void main(String[] args) {
#             int[] numbers = {5, 2, 8, 1, 9, 4};
#
#             System.out.println("Original array: " + Arrays.toString(numbers));
#
#             // Sorts the array in ascending order
#             Arrays.sort(numbers);
#
#             System.out.println("Sorted array: " + Arrays.toString(numbers));
#         }
#     }
#     ```
#
# *   **For Object Arrays (e.g., `String[]`)**
#
#     ```java
#     import java.util.Arrays;
#
#     public class SortObjectArray {
#         public static void main(String[] args) {
#             String[] names = {"Charlie", "Alice", "Bob", "David"};
#
#             System.out.println("Original array: " + Arrays.toString(names));
#
#             // Sorts the array in natural order (alphabetical for strings)
#             Arrays.sort(names);
#
#             System.out.println("Sorted array: " + Arrays.toString(names));
#         }
#     }
#     ```
#
# *   **Sorting in Descending Order (for Object Arrays)**
#
#     To sort object arrays in descending order, you can use `Collections.reverseOrder()` with `Arrays.sort()`:
#
#     ```java
#     import java.util.Arrays;
#     import java.util.Collections;
#
#     public class SortDescending {
#         public static void main(String[] args) {
#             String[] names = {"Charlie", "Alice", "Bob", "David"};
#
#             System.out.println("Original array: " + Arrays.toString(names));
#
#             // Sorts in reverse alphabetical order
#             Arrays.sort(names, Collections.reverseOrder());
#
#             System.out.println("Sorted array (descending): " + Arrays.toString(names));
#         }
#     }
#     ```
#     **Important Note:** This descending sort works for object arrays because `Collections.reverseOrder()` expects a `Comparator`, and primitive types don't have a direct `Comparator` equivalent. For primitive arrays, you'd typically sort ascending and then reverse it manually or copy it to an `Integer[]` first.
#
# *   **Sorting Arrays of Custom Objects**
#
#     If you have an array of your own custom objects, you have two main options for sorting:
#
#     *   **Implement `Comparable`:** Make your class implement the `Comparable` interface and define its "natural ordering" in the `compareTo()` method.
#
#         ```java
#         import java.util.Arrays;
#
#         class Person implements Comparable<Person> {
#             String name;
#             int age;
#
#             public Person(String name, int age) {
#                 this.name = name;
#                 this.age = age;
#             }
#
#             // Natural ordering by age
#             @Override
#             public int compareTo(Person other) {
#                 return Integer.compare(this.age, other.age);
#             }
#
#             @Override
#             public String toString() {
#                 return name + "(" + age + ")";
#             }
#         }
#
#         public class SortCustomObjectsComparable {
#             public static void main(String[] args) {
#                 Person[] people = {
#                     new Person("Alice", 30),
#                     new Person("Bob", 25),
#                     new Person("Charlie", 35)
#                 };
#
#                 System.out.println("Original array: " + Arrays.toString(people));
#
#                 Arrays.sort(people); // Uses the compareTo method
#
#                 System.out.println("Sorted array (by age): " + Arrays.toString(people));
#             }
#         }
#         ```
#
#     *   **Use a `Comparator`:** Create a separate `Comparator` class or an anonymous inner class/lambda expression to define the sorting logic. This is useful when you want to sort by different criteria or when you can't modify the original class.
#
#         ```java
#         import java.util.Arrays;
#         import java.util.Comparator;
#
#         class Person { // No Comparable here
#             String name;
#             int age;
#
#             public Person(String name, int age) {
#                 this.name = name;
#                 this.age = age;
#             }
#
#             @Override
#             public String toString() {
#                 return name + "(" + age + ")";
#             }
#         }
#
#         public class SortCustomObjectsComparator {
#             public static void main(String[] args) {
#                 Person[] people = {
#                     new Person("Alice", 30),
#                     new Person("Bob", 25),
#                     new Person("Charlie", 35)
#                 };
#
#                 System.out.println("Original array: " + Arrays.toString(people));
#
#                 // Sort by name using a Comparator (lambda expression)
#                 Arrays.sort(people, (p1, p2) -> p1.name.compareTo(p2.name));
#                 System.out.println("Sorted array (by name): " + Arrays.toString(people));
#
#                 // Sort by age using a Comparator (method reference)
#                 Arrays.sort(people, Comparator.comparingInt(p -> p.age));
#                 System.out.println("Sorted array (by age): " + Arrays.toString(people));
#
#                 // Sort by age in descending order
#                 Arrays.sort(people, Comparator.comparingInt(p -> p.age).reversed());
#                 System.out.println("Sorted array (by age descending): " + Arrays.toString(people));
#             }
#         }
#         ```
#
# **Under the Hood of `Arrays.sort()`:**
#
# *   For primitive arrays, `Arrays.sort()` uses a highly optimized dual-pivot Quicksort algorithm.
# *   For object arrays, it uses Timsort (a hybrid merge sort and insertion sort algorithm), which is generally more efficient for real-world data.
#
# **2. Sorting Using Streams (Java 8 and later)**
#
# Streams provide a functional approach to sorting. This is often more concise for simple sorts or when you want to create a new sorted collection without modifying the original array.
#
# *   **Sorting a Primitive Array and Collecting to a New Array:**
#
#     ```java
#     import java.util.Arrays;
#
#     public class SortPrimitiveArrayStream {
#         public static void main(String[] args) {
#             int[] numbers = {5, 2, 8, 1, 9, 4};
#
#             System.out.println("Original array: " + Arrays.toString(numbers));
#
#             // Sort using streams
#             int[] sortedNumbers = Arrays.stream(numbers)
#                                       .sorted() // Natural order for primitives
#                                       .toArray();
#
#             System.out.println("Sorted array: " + Arrays.toString(sortedNumbers));
#         }
#     }
#     ```
#
# *   **Sorting an Object Array and Collecting to a New Array:**
#
#     ```java
#     import java.util.Arrays;
#     import java.util.Comparator;
#
#     public class SortObjectArrayStream {
#         public static void main(String[] args) {
#             String[] names = {"Charlie", "Alice", "Bob", "David"};
#
#             System.out.println("Original array: " + Arrays.toString(names));
#
#             // Sort alphabetically using streams
#             String[] sortedNames = Arrays.stream(names)
#                                        .sorted() // Natural order for strings
#                                        .toArray(String[]::new); // Specify the type of array
#
#             System.out.println("Sorted array: " + Arrays.toString(sortedNames));
#
#             // Sort by length using streams
#             String[] sortedByLength = Arrays.stream(names)
#                                             .sorted(Comparator.comparingInt(String::length))
#                                             .toArray(String[]::new);
#
#             System.out.println("Sorted array (by length): " + Arrays.toString(sortedByLength));
#         }
#     }
#     ```
#
# **When to Choose Which Method:**
#
# *   **`Arrays.sort()`:**
#     *   **Most common:** For in-place sorting of primitive or object arrays.
#     *   **Efficiency:** Highly optimized algorithms.
#     *   **Simplicity:** Straightforward to use.
#     *   **Custom sorting:** Easily done with `Comparable` or `Comparator`.
#
# *   **Streams (`.sorted()`):**
#     *   **Java 8+:** Requires a modern Java version.
#     *   **Functional style:** Often more readable for complex transformations.
#     *   **Immutable approach:** Creates a new sorted collection, leaving the original untouched.
#     *   **Chaining operations:** Can be easily combined with other stream operations (like `filter`, `map`).
#     *   **Slight overhead:** For very small arrays, `Arrays.sort()` might be marginally faster due to stream overhead.
#
# **Manual Sorting Algorithms (For Learning or Specific Needs):**
#
# While `Arrays.sort()` is almost always preferred in production code, understanding manual sorting algorithms is crucial for computer science fundamentals and for situations where you might need to implement a custom sorting logic not covered by standard libraries (though this is rare).
#
# Common manual algorithms include:
#
# *   **Bubble Sort:** Simple but inefficient (O(n^2)).
# *   **Selection Sort:** Also simple and inefficient (O(n^2)).
# *   **Insertion Sort:** Efficient for nearly sorted arrays (O(n^2) worst-case, O(n) best-case).
# *   **Merge Sort:** Efficient (O(n log n)), stable, but requires extra space.
# *   **Quick Sort:** Efficient (O(n log n) average, O(n^2) worst-case), often used in `Arrays.sort()`.
# *   **Heap Sort:** Efficient (O(n log n)), in-place.
#
# **Example of Bubble Sort (for educational purposes):**
#
# ```java
# import java.util.Arrays;
#
# public class BubbleSort {
#     public static void main(String[] args) {
#         int[] numbers = {5, 2, 8, 1, 9, 4};
#
#         System.out.println("Original array: " + Arrays.toString(numbers));
#
#         bubbleSort(numbers);
#
#         System.out.println("Sorted array (Bubble Sort): " + Arrays.toString(numbers));
#     }
#
#     public static void bubbleSort(int[] arr) {
#         int n = arr.length;
#         boolean swapped;
#         for (int i = 0; i < n - 1; i++) {
#             swapped = false;
#             for (int j = 0; j < n - 1 - i; j++) {
#                 if (arr[j] > arr[j + 1]) {
#                     // Swap arr[j] and arr[j+1]
#                     int temp = arr[j];
#                     arr[j] = arr[j + 1];
#                     arr[j + 1] = temp;
#                     swapped = true;
#                 }
#             }
#             // If no two elements were swapped by inner loop, then break
#             if (!swapped) break;
#         }
#     }
# }
# ```
#
# **In summary, for most practical Java development:**
#
# *   **Use `Arrays.sort()`** for in-place sorting.
# *   **Use Streams (`.sorted()`)** when you prefer a functional approach or need to create a new sorted collection.
# *   Implement `Comparable` or `Comparator` when sorting custom objects.
#
# Let me know if you have a specific type of array or sorting requirement in mind, and I can provide a more tailored example!
