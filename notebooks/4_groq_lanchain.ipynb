# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")

# %%
res = llm.invoke("What is sanskar")

# %%
print(res.content)
# Out:
# **Sanskar (संस् कार)** – a Sanskrit word that literally means *“to form, shape, or mould.”*
# In everyday Indian life it is often translated as *“values,”* *“culture,”* or *“ritual.”*  It is a central concept in many Indian philosophical, religious, and social traditions, and it is used in a few distinct ways:
#
# | Context | What *sanskar* refers to | Key points |
# |---------|--------------------------|------------|
# | **Vedic / Ritual** | *Samskara* (संस् कार) – the rites of passage that mark a person’s life stages (birth, initiation, marriage, death). | 12 major samskaras in Hindu tradition; each one is a ritual that “sculpts” the soul’s spiritual development. |
# | **Psychology / Personal Development** | The internalized patterns of thought, feeling, and action that are formed by upbringing, education, and experience. | These “inner‑samskaras” influence a person’s behaviour, attitudes, and moral compass. |
# ...

# %%
res = llm.invoke("What is audacity,relate to real-life")
print(res.content)
# Out:
# **Audacity**
# > *noun* – the quality of being bold or daring; a willingness to take risks, to act without fear, or to challenge conventions.
#
# In everyday language, “audacity” is often used to describe someone who does something that feels surprising, bold, or even reckless. It can be a compliment (“She has the audacity to stand up for what she believes in”) or a criticism (“He’s got the audacity to ask for a raise after just one month on the job?”).
#
# ---
#
# ## How Audacity Plays Out in Real Life
#
# | Situation | What the Audacity Looks Like | Why It Matters |
# |-----------|-----------------------------|----------------|
# | **Career moves** | Switching industries, starting a business, or asking for a big raise. | Signals confidence and a willingness to grow; can lead to bigger opportunities. |
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
openaillm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
res = openaillm.invoke("What is audacity,relate to real-life")
print(res.content)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Audacity, in its most common and positive sense, refers to **boldness, daring, and a willingness to take risks or challenge conventions, often in the face of potential disapproval or danger.** It's about having the courage to act according to one's convictions, even when it's difficult or unpopular.
#
# Here's how audacity relates to real-life, broken down into different aspects:
#
# **1. Innovation and Progress:**
#
# ...
